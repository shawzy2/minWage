# %% [markdown]
# # Mine Player Statistics

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
import requests
import json
import pprint
import time

import pandas as pd

# fix ssl certificate (needed for MacOS sometimes)
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# /Users/davidshaw/Projects/minWage/env/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# read in contracts
df_contracts = pd.read_csv('contracts_tilJuly2024.csv')

# %%
CAP_FRIENDLY_BASE_URL = 'https://www.capfriendly.com'

def get_soup(url):
    page = urlopen(url)
    html = page.read().decode("utf-8")
    soup = BeautifulSoup(html, 'html.parser')
    return soup

# %%
def scrape_player_stats(player_link):
    # get soup
    player_soup = get_soup(CAP_FRIENDLY_BASE_URL + player_link)
    
    # parse tables
    this_player_stats = []
    this_player_position = get_position(player_soup)
    for row in player_soup.find('table', {'id': 'career_stats'}).find('tbody').find_all('tr'):
        player_stats = [player_link, this_player_position]
        for cell in row.find_all('td'):
            clazz = cell.get('class')
            if clazz is not None:
                if 'hide' in clazz:
                    continue
            player_stats.append(cell.get_text())
        this_player_stats.append(player_stats)
    return this_player_stats

def get_position(player_soup):
    for h6 in player_soup.find_all('h6', {'class': 'c'}):
        for position in ['centre', 'wing', 'defense', 'goaltender']:
            if position in h6.get_text().lower():
                return h6.get_text()

def fill_in_missing_seasons(this_player_stats):
    cur_season = None
    for row in this_player_stats:
        # set cur_season to first row season
        if cur_season is None:
            cur_season = row[2]
            continue

        # check if season is empty, set to value of previous row
        if row[2] == '':
            row[2] = cur_season
        else:
            cur_season = row[2]
    return this_player_stats

# %%
count = 0
all_player_stats = []
for player_link in df_contracts['playerLink'].unique()[count:]:
    this_player_stats = []
    try:
        this_player_stats = scrape_player_stats(player_link)
        this_player_stats = fill_in_missing_seasons(this_player_stats)
    except Exception as e:
        print(f'could not scrape link: {player_link}', e)
    all_player_stats.extend(this_player_stats)
    
    count += 1
    if count % 100 == 0:
        percent_remaining = round((1 - count / len(df_contracts['playerLink'].unique())) * 100, 1)
        print(f'through {count} players; {percent_remaining}% remaining')
# Out:
# through 100 players; 97.5% remaining
# through 200 players; 95.0% remaining
# through 300 players; 92.5% remaining
# through 400 players; 90.0% remaining
# through 500 players; 87.5% remaining
# through 600 players; 85.0% remaining
# through 700 players; 82.5% remaining
# through 800 players; 80.0% remaining
# through 900 players; 77.5% remaining
# through 1000 players; 75.0% remaining
# through 1100 players; 72.5% remaining
# through 1200 players; 70.0% remaining
# through 1300 players; 67.5% remaining
# through 1400 players; 64.9% remaining
# through 1500 players; 62.4% remaining
# through 1600 players; 59.9% remaining
# through 1700 players; 57.4% remaining
# through 1800 players; 54.9% remaining
# through 1900 players; 52.4% remaining
# through 2000 players; 49.9% remaining
# through 2100 players; 47.4% remaining
# through 2200 players; 44.9% remaining
# through 2300 players; 42.4% remaining
# through 2400 players; 39.9% remaining
# through 2500 players; 37.4% remaining
# through 2600 players; 34.9% remaining
# through 2700 players; 32.4% remaining
# through 2800 players; 29.9% remaining
# through 2900 players; 27.4% remaining
# through 3000 players; 24.9% remaining
# through 3100 players; 22.4% remaining
# through 3200 players; 19.9% remaining
# through 3300 players; 17.4% remaining
# through 3400 players; 14.9% remaining
# through 3500 players; 12.4% remaining
# through 3600 players; 9.9% remaining
# through 3700 players; 7.4% remaining
# through 3800 players; 4.9% remaining
# through 3900 players; 2.4% remaining

# %%
df = pd.DataFrame(all_player_stats)
df.columns = ['playerLink', 'position', 'season', 'teamName', 'leagueName', 'nullCol1', 
              'gamesPlayed', 'goals', 'assists', 'points', 'plusMinus', 'pim', 'nullCol2', 'nullCol3',
              'gamesPlayedPlayoff', 'goalsPlayoff', 'assistsPlayoff', 'pointsPlayoff', 'plusMinusPlayoff', 'pimPlayoff']
df.to_csv('playerStats_tilJuly2024.csv', index=False)
df.head(10)
# Out:
#                   playerLink               position   season  \
# 0  /players/viktor-arvidsson  Right Wing, Left Wing  2008-09
# 1  /players/viktor-arvidsson  Right Wing, Left Wing  2008-09
# 2  /players/viktor-arvidsson  Right Wing, Left Wing  2009-10
# 3  /players/viktor-arvidsson  Right Wing, Left Wing  2009-10
# 4  /players/viktor-arvidsson  Right Wing, Left Wing  2009-10
# 5  /players/viktor-arvidsson  Right Wing, Left Wing  2009-10
# 6  /players/viktor-arvidsson  Right Wing, Left Wing  2009-10
# 7  /players/viktor-arvidsson  Right Wing, Left Wing  2010-11
# 8  /players/viktor-arvidsson  Right Wing, Left Wing  2010-11
# 9  /players/viktor-arvidsson  Right Wing, Left Wing  2010-11
#
#              teamName        leagueName nullCol1 gamesPlayed goals assists  \
# 0    Sweden U16 (all)  International-Jr                    3     2       2
# 1  Skellefteå AIK J18     J18 Nationell                   14     7       7
# 2    Sweden U17 (all)  International-Jr                    9     4       5
# 3          Sweden U17            WHC-17                    6     2       2
# 4  Skellefteå AIK J18        J18 Region                   22    32      30
# 5  Skellefteå AIK J20     J20 Nationell                    2     0       1
# 6  Skellefteå AIK J18     J18 Nationell                   18    20      18
# 7      Skellefteå AIK               SHL                    3     0       0
# 8    Sweden U18 (all)  International-Jr                   19     9       6
# 9          Sweden U18            WJC-18                    5     0       1
#
#   points plusMinus pim nullCol2  nullCol3 gamesPlayedPlayoff goalsPlayoff  \
# 0      4         -   0        |
# 1     14         -  16        |  PLAYOFFS                  5            1
# 2      9         -   6        |
# 3      4         -   2        |
# 4     62         -  34        |
# 5      1         -   2        |  PLAYOFFS                  2            1
# 6     38         -  26        |  PLAYOFFS                  3            1
# 7      0         0   0        |
# 8     15         2  18        |
# 9      1        -1   8        |
#
#   assistsPlayoff pointsPlayoff plusMinusPlayoff pimPlayoff
# 0
# 1              2             3                           4
# 2
# 3
# 4
# 5              0             1                           0
# 6              1             2                           0
# 7
# 8
# 9

# %% [markdown]
# ------------------

# %%
df[df['playerLink']=='/players/nathan-mackinnon'].sort_values('season')
# Out:
#                       playerLink position   season  \
# 17807  /players/nathan-mackinnon   Centre  2009-10
# 17808  /players/nathan-mackinnon   Centre  2010-11
# 17809  /players/nathan-mackinnon   Centre  2010-11
# 17810  /players/nathan-mackinnon   Centre  2010-11
# 17811  /players/nathan-mackinnon   Centre  2011-12
# 17812  /players/nathan-mackinnon   Centre  2011-12
# 17813  /players/nathan-mackinnon   Centre  2011-12
# 17814  /players/nathan-mackinnon   Centre  2012-13
# 17815  /players/nathan-mackinnon   Centre  2012-13
# 17816  /players/nathan-mackinnon   Centre  2012-13
# 17817  /players/nathan-mackinnon   Centre  2012-13
# 17818  /players/nathan-mackinnon   Centre  2012-13
# 17820  /players/nathan-mackinnon   Centre  2013-14
# 17819  /players/nathan-mackinnon   Centre  2013-14
# 17821  /players/nathan-mackinnon   Centre  2014-15
# 17822  /players/nathan-mackinnon   Centre  2014-15
# 17823  /players/nathan-mackinnon   Centre  2015-16
# 17824  /players/nathan-mackinnon   Centre  2016-17
# 17825  /players/nathan-mackinnon   Centre  2016-17
# 17826  /players/nathan-mackinnon   Centre  2016-17
# 17827  /players/nathan-mackinnon   Centre  2017-18
# 17828  /players/nathan-mackinnon   Centre  2018-19
# 17829  /players/nathan-mackinnon   Centre  2019-20
# 17830  /players/nathan-mackinnon   Centre  2020-21
# 17831  /players/nathan-mackinnon   Centre  2021-22
# 17832  /players/nathan-mackinnon   Centre  2022-23
# 17833  /players/nathan-mackinnon   Centre  2023-24
#
#                            teamName          leagueName nullCol1 gamesPlayed  \
# 17807  Shattuck St. Marys Bantam T1             14U AAA                   58
# 17808           Canada Atlantic U17              WHC-17                    5
# 17809              Team Nova Scotia                 CWG                    7
# 17810        Shattuck St. Marys U16             16U AAA                   40
# 17811            Halifax Mooseheads               QMJHL                   58
# 17812           Canada Atlantic U17              WHC-17                    5
# 17813               QMJHL All-Stars     Jr Super Series                    2
# 17814            Halifax Mooseheads               QMJHL                   44
# 17815                    Canada U18  Hlinka Gretzky Cup                    5
# 17816                    Canada U20              WJC-20                    6
# 17817               QMJHL All-Stars     Jr Super Series                    2
# 17818            Halifax Mooseheads        Memorial Cup                    4
# 17820                        Canada                  WC                    8
# 17819            Colorado Avalanche                 NHL                   82
# 17821            Colorado Avalanche                 NHL                   64
# 17822                        Canada                  WC                   10
# 17823            Colorado Avalanche                 NHL                   72
# 17824            Colorado Avalanche                 NHL                   82
# 17825                        Canada                  WC                   10
# 17826            Team North America                WCup                    3
# 17827            Colorado Avalanche                 NHL                   74
# 17828            Colorado Avalanche                 NHL                   82
# 17829            Colorado Avalanche                 NHL                   69
# 17830            Colorado Avalanche                 NHL                   48
# 17831            Colorado Avalanche                 NHL                   65
# 17832            Colorado Avalanche                 NHL                   71
# 17833            Colorado Avalanche                 NHL                   82
#
#       goals assists points plusMinus pim nullCol2  nullCol3  \
# 17807    54      47    101         -  56        |
# 17808     5       3      8         -   0        |
# 17809     8       3     11         -   8        |
# 17810    45      48     93         -  72        |
# 17811    31      47     78        11  45        |  PLAYOFFS
# 17812     1       3      4         -   2        |
# 17813     0       0      0         0   2        |
# 17814    32      43     75        40  45        |  PLAYOFFS
# 17815     5       6     11         8  14        |
# 17816     0       1      1        -1   4        |
# 17817     1       3      4        -2   2        |
# 17818     7       6     13         8   0        |
# 17820     1       3      4         3   8        |
# 17819    24      39     63        20  26        |  PLAYOFFS
# 17821    14      24     38        -7  34        |
# 17822     4       5      9         6   6        |
# 17823    21      31     52        -4  20        |
# 17824    16      37     53       -14  16        |
# 17825     6       9     15         6   6        |
# 17826     2       1      3         2   2        |
# 17827    39      58     97        11  55        |  PLAYOFFS
# 17828    41      58     99        20  34        |  PLAYOFFS
# 17829    35      58     93        13  12        |  PLAYOFFS
# 17830    20      45     65        22  37        |  PLAYOFFS
# 17831    32      56     88        22  42        |  PLAYOFFS
# 17832    42      69    111        29  30        |  PLAYOFFS
# 17833    51      89    140        35  42        |  PLAYOFFS
#
#       gamesPlayedPlayoff goalsPlayoff assistsPlayoff pointsPlayoff  \
# 17807
# 17808
# 17809
# 17810
# 17811                 17           13             15            28
# 17812
# 17813
# 17814                 17           11             22            33
# 17815
# 17816
# 17817
# 17818
# 17820
# 17819                  7            2              8            10
# 17821
# 17822
# 17823
# 17824
# 17825
# 17826
# 17827                  6            3              3             6
# 17828                 12            6              7            13
# 17829                 15            9             16            25
# 17830                 10            8              7            15
# 17831                 20           13             11            24
# 17832                  7            3              4             7
# 17833                 11            4             10            14
#
#       plusMinusPlayoff pimPlayoff
# 17807
# 17808
# 17809
# 17810
# 17811               12         12
# 17812
# 17813
# 17814               17         12
# 17815
# 17816
# 17817
# 17818
# 17820
# 17819                2          4
# 17821
# 17822
# 17823
# 17824
# 17825
# 17826
# 17827               -2          4
# 17828               -4          2
# 17829               13         12
# 17830                6          2
# 17831               11          8
# 17832                8          4
# 17833               -1          4
